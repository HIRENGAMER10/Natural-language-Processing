# %%
import nltk
import spacy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("done all")
# Out:
# done all

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
string = "Hey Simran I am with you for the entire life !"
print(string)
data = nlp(string)
# PRINT TOKENIZED WORDS
for token in data:
    print(token.text,end=" | ")
# Out:
# Hey Simran I am with you for the entire life !
# Hey | Simran | I | am | with | you | for | the | entire | life | ! |

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
data = nlp(u"Hey Simran I am here to help! call me , msg me or email me")
for token in data:
    print(token)
# Out:
# Hey
# Simran
# I
# am
# here
# to
# help
# !
# call
# me
# ,
# msg
# me
# or
# email
# me

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
data = nlp(u"I have total $10.20 and I am going to buy $2.30 choco")
for token in data:
    print(token)
# Out:
# I
# have
# total
# $
# 10.20
# and
# I
# am
# going
# to
# buy
# $
# 2.30
# choco

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
data = nlp(u"Let's visit st.louis in the US next year")
for token in data:
    print(token)
print(len(data))
# Out:
# Let
# 's
# visit
# st.louis
# in
# the
# US
# next
# year
# 9

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
data = nlp(u"Let's visit st.louis in the US next year")
print(data[2])
# Out:
# visit

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
data = nlp(u"Let's visit st.louis in the US next year")
print(data[2])
print(data[2:5])
# Out:
# visit
# visit st.louis in

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
data = nlp(u"Apple to build a India factory for $6 million")
print("Detailed Token Label Information")
for token in data:
    print(token.text + " | " + token.ent_type_ + " | " + str(spacy.explain(token.ent_type_)))
# Out:
# Detailed Token Label Information
# Apple | ORG | Companies, agencies, institutions, etc.
# to |  | None
# build |  | None
# a |  | None
# India | GPE | Countries, cities, states
# factory |  | None
# for |  | None
# $ | MONEY | Monetary values, including unit
# 6 | MONEY | Monetary values, including unit
# million | MONEY | Monetary values, including unit
# /usr/local/lib/python3.10/dist-packages/spacy/glossary.py:20: UserWarning: [W118] Term '' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
data = nlp(u"Apple to build a India factory for $6 million")
print("Detailed Token Label Information")
for token in data.ents:
    print(token.text + " | " + token.label_ + " | " + str(spacy.explain(token.label_)))
# Out:
# Detailed Token Label Information
# Apple | ORG | Companies, agencies, institutions, etc.
# India | GPE | Countries, cities, states
# $6 million | MONEY | Monetary values, including unit

# %%
import nltk
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
words = ["running","jumps","jumped","flies","happily","better","betterment"]
for word in words:
    print(word + " --> " + stemmer.stem(word))
# Out:
# running --> run
# jumps --> jump
# jumped --> jump
# flies --> fli
# happily --> happili
# better --> better
# betterment --> better

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer
snowball_stem=SnowballStemmer("english")
words = ["running","jumps","jumped","flies","happily","better","betterment"]
for word in words:
    print(word + " --> " + snowball_stem.stem(word))
# Out:
# running --> run
# jumps --> jump
# jumped --> jump
# flies --> fli
# happily --> happili
# better --> better
# betterment --> better

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
snowball_stem=SnowballStemmer("english")
words = ["consolingly"]
for word in words:
    print(word + " --> " + stemmer.stem(word))
for word in words:
    print(word + " --> " + snowball_stem.stem(word))
# Out:
# consolingly --> consolingli
# consolingly --> consol

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
data = nlp("The striped bats are hanging on their feet for best")
for token in data:
    print(token.text + " | " + token.lemma_)
# Out:
# The | the
# striped | stripe
# bats | bat
# are | be
# hanging | hang
# on | on
# their | their
# feet | foot
# for | for
# best | good

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
data = "The striped bats are hanging on their feet for best"
for token in data.split():
    print(token + " | " + stemmer.stem(token))
# Out:
# The | the
# striped | stripe
# bats | bat
# are | are
# hanging | hang
# on | on
# their | their
# feet | feet
# for | for
# best | best

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
import nltk
nltk.download('stopwords')
print(nlp.Defaults.stop_words)
print(len(nlp.Defaults.stop_words))
# Out:
# {'across', 'either', 'will', 'third', 'whereby', 'neither', 'on', 'yours', 'with', 'another', 'ourselves', 'thus', 'you', 'what', 'behind', 'alone', 'very', 'also', 'once', '’re', 'nothing', 'made', 'each', 'just', 'latterly', 'such', 'becomes', 'nor', 'first', 'herself', 'anyone', 'twelve', 'same', 'can', 'which', 'elsewhere', 'via', 'that', 'because', 'perhaps', 'per', 'me', 'call', 'her', 'get', 'his', 'until', 'nine', 'nevertheless', 'really', 'therefore', 'over', 'hence', 'a', 'ours', 'else', 'be', 'never', 'own', 'from', 'sometime', 'much', 'someone', 'itself', 'does', 'beyond', 'since', 'less', 'least', 'quite', 'thence', 'during', 'fifty', 'off', 'should', 'became', 'whether', 'them', 'part', 'empty', "'ll", 'after', 'meanwhile', 'whoever', 'used', 'he', '’m', 'for', "'s", 'our', 'onto', 'towards', 'move', 'then', 'yourself', 'two', 'none', 'we', 'six', "'re", 'rather', 'doing', 'hundred', 'please', "'ve", 'back', 'few', 'has', 'ca', 'i', 'or', 'ever', 'if', 'up', 'could', 't
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
print("Length before : ",len(nlp.Defaults.stop_words))
print(nlp.vocab['finance'].is_stop)
print(nlp.vocab['always'].is_stop)
print(nlp.vocab['shyam'].is_stop)
nlp.Defaults.stop_words.add('shyam')
nlp.vocab['shyam'].is_stop = True
print("Length after : ",len(nlp.Defaults.stop_words))
print(nlp.vocab['shyam'].is_stop)
# Out:
# Length before :  324
# False
# False
# True
# Length after :  324
# True

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
import nltk
nltk.download('stopwords')
print(nlp.Defaults.stop_words)
print(len(nlp.Defaults.stop_words))
# Out:
# {'above', '’ve', 'something', 'its', 'anywhere', 'a', 'only', 'along', 'whither', 'latterly', 'further', 'whom', 're', 'your', '’s', 'nor', 'ca', 'elsewhere', 'has', 'please', 'whereafter', 'now', 'n‘t', 'does', 'full', 'could', 'really', 'enough', 'once', 'onto', 'there', 'one', 'thus', 'neither', 'never', 'each', 'hereupon', 'noone', 'shyam', 'had', "'ll", 'with', 'his', "'ve", 'no', 'namely', '‘d', 'except', 'whereby', 'might', 'over', '’re', 'besides', 'through', 'thereupon', 'another', 'every', 'beside', 'mostly', 'became', 'twelve', 'yet', 'thence', 'to', 'next', 'give', 'be', 'whoever', 'here', 'that', "'re", 'fifty', 'wherever', 'bottom', 'nowhere', 'until', 'therefore', 'nothing', 'back', 'see', 'quite', 'whereupon', 'do', 'around', 'upon', 'would', 'three', 'yourself', 'so', 'regarding', 'were', 'sixty', 'i', 'fifteen', 'herself', 'doing', 'and', 'below', 'she', 'any', 'serious', 'twenty', 'several', 'due', 'herein', 'empty', 'none', '‘m', 'per', 'otherwise', 'two', '’d', '
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("Apple is looking at buying India startup for $1 billion")
for ent in doc.ents:
    print(ent.text + " = " + ent.label_ + " ( " + str(spacy.explain(ent.label_))+")")
# Out:
# Apple | ORG | Companies, agencies, institutions, etc.
# India | GPE | Countries, cities, states
# $1 billion | MONEY | Monetary values, including unit

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("May I go to USA")
for ent in doc.ents:
    print(ent.text + " = " + ent.label_ + " ( " + str(spacy.explain(ent.label_))+")")
# Out:
# USA = GPE ( Countries, cities, states)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("Can I Please borrow 500 dollars from Rahul to buy some Reliance Stock?")
for ent in doc.ents:
    print(ent.text + " = " + str(ent.start) + " = " + str(ent.end) + " = " + str(ent.start_char)+ " = " + str(ent.end_char)+ " = " + ent.label_ + " ( " + str(spacy.explain(ent.label_))+")")
# Out:
# 500 dollars = 4 = 6 = 20 = 31 = MONEY ( Monetary values, including unit)
# Rahul = 7 = 8 = 37 = 42 = NORP ( Nationalities or religious or political groups)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy import displacy
s1 = nlp("Apple is looking at buying U.K. startup for $1 billion. San Francisco considers banning sidewalk delivery robots. facebook is hiring a new  vice president in U.S.")
doc1=nlp(s1)
displacy.render(docs=doc1,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is looking at buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1 billion
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("This is first sentence.This is second sentence.This is third sentence")
for sent in doc.sents:
    print(sent.text)
# Out:
# This is first sentence.
# This is second sentence.
# This is third sentence

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("This is first sentence.This is second sentence.This is third sentence")
doc_sents = [sent for sent in doc.sents]
print(doc_sents)
print(doc_sents[1])
print(doc_sents[1].start,doc_sents[1].end)
# Out:
# [This is first sentence., This is second sentence., This is third sentence]
# This is second sentence.
# 5 10

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("This is first sentence.This is second sentence.This is third sentence")
for token in doc:
    print(token.is_sent_start,' = ' + token.text)
# Out:
# True  = This
# False  = is
# False  = first
# False  = sentence
# False  = .
# True  = This
# False  = is
# False  = second
# False  = sentence
# False  = .
# True  = This
# False  = is
# False  = third
# False  = sentence

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
doc =nlp(doc)
for token in doc:
    print(token.text, " - ",token.pos_," - ", token.tag_," - ",spacy.explain(token.tag_))
# Out:
# Apple  -  PROPN  -  NNP  -  noun, proper singular
# is  -  AUX  -  VBZ  -  verb, 3rd person singular present
# looking  -  VERB  -  VBG  -  verb, gerund or present participle
# at  -  ADP  -  IN  -  conjunction, subordinating or preposition
# buying  -  VERB  -  VBG  -  verb, gerund or present participle
# U.K.  -  PROPN  -  NNP  -  noun, proper singular
# startup  -  NOUN  -  NN  -  noun, singular or mass
# for  -  ADP  -  IN  -  conjunction, subordinating or preposition
# $  -  SYM  -  $  -  symbol, currency
# 1  -  NUM  -  CD  -  cardinal number
# billion  -  NUM  -  CD  -  cardinal number

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
s1= "Apple is looking at buying U.K. startup for $1 billion"
doc = nlp(s1)
for token in doc:
    print(f"Text: {token.text}")
    print(f"Lemma: {token.lemma_}")
    print(f"POS: {token.pos_}")
    print(f"Tag: {token.tag_}- {spacy.explain(token.tag_)}")
    print(f"Dependency: {token.dep_}")
    print(f"Shape: {token.shape_}")
    print(f"is alpha: {token.is_alpha}")
    print(f"is stop word: {token.is_stop}")
    print("\n")
# Out:
# Text: Apple
# Lemma: Apple
# POS: PROPN
# Tag: NNP- noun, proper singular
# Dependency: nsubj
# Shape: Xxxxx
# is alpha: True
# is stop word: False
#
#
# Text: is
# Lemma: be
# POS: AUX
# Tag: VBZ- verb, 3rd person singular present
# Dependency: aux
# Shape: xx
# is alpha: True
# is stop word: True
#
#
# Text: looking
# Lemma: look
# POS: VERB
# Tag: VBG- verb, gerund or present participle
# Dependency: ROOT
# Shape: xxxx
# is alpha: True
# is stop word: False
#
#
# Text: at
# Lemma: at
# POS: ADP
# Tag: IN- conjunction, subordinating or preposition
# Dependency: prep
# Shape: xx
# is alpha: True
# is stop word: True
#
#
# Text: buying
# Lemma: buy
# POS: VERB
# Tag: VBG- verb, gerund or present participle
# Dependency: pcomp
# Shape: xxxx
# is alpha: True
# is stop word: False
#
#
# Text: U.K.
# Lemma: U.K.
# POS: PROPN
# Tag: NNP- noun, proper singular
# Dependency: dobj
# Shape: X.X.
# is alpha: False
# is stop word: False
#
#
# Text: startup
# Lemma: startup
# POS: NOUN
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

text = ["the quick brown fox jumped over the lazy dog"]

vectorizer = CountVectorizer()
vectorizer.fit(text)
print(vectorizer.vocabulary_)

vector = vectorizer.transform(text)
print(vector.shape)
print(type(vector))
print(vector.toarray())
# Out:
# {'the': 7, 'quick': 6, 'brown': 0, 'fox': 2, 'jumped': 3, 'over': 5, 'lazy': 4, 'dog': 1}
# (1, 8)
# <class 'scipy.sparse._csr.csr_matrix'>
# [[1 1 1 1 1 1 1 2]]

# %%
from nltk import word_tokenize, FreqDist

text = "The lion is a wild animal. The tiger is a wild animal too"

words = word_tokenize(text)

freq_dist = FreqDist(words)

print("Word Frequency Distribution:")
print(freq_dist.most_common())
# Out:
# Word Frequency Distribution:
# [('The', 2), ('is', 2), ('a', 2), ('wild', 2), ('animal', 2), ('lion', 1), ('.', 1), ('tiger', 1), ('too', 1)]

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

data = nlp(u"The big brown dog chased the fluffy white cat")

for chunk in data.noun_chunks:
	print(chunk.text)
# Out:
# The big brown dog
# the fluffy white cat
